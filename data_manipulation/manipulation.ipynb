# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dfo = pd.read_csv('../data/P87-S7-Advanced-Manipulation-Resources/flights2.csv.gz')
print(dfo.columns)
dfo.head()
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# ...

# %%
dfo.isna().mean().sort_values(ascending=False) *100
# Out:
# CANCELLATION_REASON    97.450465
# WEATHER_DELAY          79.583504
# LATE_AIRCRAFT_DELAY    79.583504
# AIRLINE_DELAY          79.583504
# SECURITY_DELAY         79.583504
# AIR_SYSTEM_DELAY       79.583504
# AIR_TIME                2.756571
# ARRIVAL_DELAY           2.756571
# ELAPSED_TIME            2.756571
# WHEELS_ON               2.611029
# TAXI_IN                 2.611029
# ARRIVAL_TIME            2.611029
# TAXI_OUT                2.526981
# WHEELS_OFF              2.526981
# DEPARTURE_DELAY         2.480382
# DEPARTURE_TIME          2.480382
# TAIL_NUMBER             0.591955
# SCHEDULED_DEPARTURE     0.000000
# CANCELLED               0.000000
# DAY                     0.000000
# DAY_OF_WEEK             0.000000
# AIRLINE                 0.000000
# FLIGHT_NUMBER           0.000000
# SCHEDULED_ARRIVAL       0.000000
# DIVERTED                0.000000
# ORIGIN_AIRPORT          0.000000
# DISTANCE                0.000000
# DESTINATION_AIRPORT     0.000000
# ...

# %%
df = dfo.copy()
df.set_index(['DESTINATION_AIRPORT','AIRLINE'], inplace=True)
df.drop(columns=["CANCELLATION_REASON", "WEATHER_DELAY", "LATE_AIRCRAFT_DELAY", "AIRLINE_DELAY", "SECURITY_DELAY",
"AIR_SYSTEM_DELAY" ], inplace=True)
df.sort_index(inplace=True)

# %%
dfo[(dfo.AIRLINE == "AA") & (dfo.DESTINATION_AIRPORT == 'LAX')]
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 443     2015      1    1            4      AA           1361      N3KYAA
# 808     2015      1    1            4      AA           2401      N858AA
# 867     2015      1    1            4      AA              9      N792AA
# 871     2015      1    1            4      AA            201      N3LJAA
# 880     2015      1    1            4      AA           1529      N5DHAA
# ...      ...    ...  ...          ...     ...            ...         ...
# 469773  2015      1   31            6      AA            298      N5ECAA
# 469834  2015      1   31            6      AA           2491      N3EVAA
# 469865  2015      1   31            6      AA            246      N5DEAA
# 469897  2015      1   31            6      AA             14      N5FBAA
# 469915  2015      1   31            6      AA            286      N5DFAA
#
#        ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
df.loc[('LAX','AA')].head()
# Out:
#                              YEAR  MONTH  DAY  DAY_OF_WEEK  FLIGHT_NUMBER  \
# DESTINATION_AIRPORT AIRLINE
# LAX                 AA       2015      1    1            4           1361
#                     AA       2015      1    1            4           2401
#                     AA       2015      1    1            4              9
#                     AA       2015      1    1            4            201
#                     AA       2015      1    1            4           1529
#
#                             TAIL_NUMBER ORIGIN_AIRPORT  SCHEDULED_DEPARTURE  \
# DESTINATION_AIRPORT AIRLINE
# LAX                 AA           N3KYAA            BNA                  610
#                     AA           N858AA            DFW                  655
#                     AA           N792AA            JFK                  700
#                     AA           N3LJAA            BOS                  700
#                     AA           N5DHAA            MCO                  700
#
# ...

# %%
dfo.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
df.head()
# Out:
#                              YEAR  MONTH  DAY  DAY_OF_WEEK  FLIGHT_NUMBER  \
# DESTINATION_AIRPORT AIRLINE
# ABE                 DL       2015      1    4            7           2036
#                     DL       2015      1    5            1           1411
#                     DL       2015      1    6            2           1411
#                     DL       2015      1    7            3           1411
#                     DL       2015      1    8            4           1411
#
#                             TAIL_NUMBER ORIGIN_AIRPORT  SCHEDULED_DEPARTURE  \
# DESTINATION_AIRPORT AIRLINE
# ABE                 DL           N979AT            ATL                 2101
#                     DL           N989AT            ATL                 2034
#                     DL           N979AT            ATL                 2034
#                     DL           N958AT            ATL                 2034
#                     DL           N994AT            ATL                 2034
#
# ...

# %%
data = {'Score': [88, 92, 85, 94, 90, 78]}
dfc = pd.DataFrame(data, index=[['School A', 'School A', 'School B', 'School B', 'School C', 'School C'], 
                               ['Grade 10', 'Grade 11', 'Grade 10', 'Grade 11', 'Grade 10', 'Grade 11']])

# Setting the multi-index
dfc.index.names = ['School', 'Grade']
dfc
# Out:
#                    Score
# School   Grade
# School A Grade 10     88
#          Grade 11     92
# School B Grade 10     85
#          Grade 11     94
# School C Grade 10     90
#          Grade 11     78

# %%
df.loc["ABQ"].head()
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK  FLIGHT_NUMBER TAIL_NUMBER  \
# AIRLINE
# AA       2015      1    1            4           1662      N4WJAA
# AA       2015      1    1            4           1024      N505AA
# AA       2015      1    1            4           1203      N4XPAA
# AA       2015      1    1            4           2388      N486AA
# AA       2015      1    2            5           1662      N582AA
#
#         ORIGIN_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  \
# AIRLINE
# AA                 DFW                 1045             NaN              NaN
# AA                 DFW                 1400          1408.0              8.0
# AA                 DFW                 1840          1853.0             13.0
# AA                 DFW                 2115          2126.0             11.0
# AA                 DFW                 1045          1044.0             -1.0
#
#          ...  ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  \
# AIRLINE  ...
# ...

# %%
df.loc["ABE":'ABQ'].head()
# Out:
#                              YEAR  MONTH  DAY  DAY_OF_WEEK  FLIGHT_NUMBER  \
# DESTINATION_AIRPORT AIRLINE
# ABE                 DL       2015      1    4            7           2036
#                     DL       2015      1    5            1           1411
#                     DL       2015      1    6            2           1411
#                     DL       2015      1    7            3           1411
#                     DL       2015      1    8            4           1411
#
#                             TAIL_NUMBER ORIGIN_AIRPORT  SCHEDULED_DEPARTURE  \
# DESTINATION_AIRPORT AIRLINE
# ABE                 DL           N979AT            ATL                 2101
#                     DL           N989AT            ATL                 2034
#                     DL           N979AT            ATL                 2034
#                     DL           N958AT            ATL                 2034
#                     DL           N994AT            ATL                 2034
#
# ...

# %%
df.loc[('ABE', 'EV'):('ADQ', 'AS')].tail()
# Out:
#                              YEAR  MONTH  DAY  DAY_OF_WEEK  FLIGHT_NUMBER  \
# DESTINATION_AIRPORT AIRLINE
# ADQ                 AS       2015      1   27            2             49
#                     AS       2015      1   28            3             49
#                     AS       2015      1   29            4             49
#                     AS       2015      1   30            5             49
#                     AS       2015      1   31            6             49
#
#                             TAIL_NUMBER ORIGIN_AIRPORT  SCHEDULED_DEPARTURE  \
# DESTINATION_AIRPORT AIRLINE
# ADQ                 AS           N768AS            ANC                 1530
#                     AS           N768AS            ANC                 1530
#                     AS           N765AS            ANC                 1530
#                     AS           N763AS            ANC                 1530
#                     AS           N794AS            ANC                 1530
#
# ...

# %%
df.loc[(slice(None), "AA"),:].head()
# Out:
#                              YEAR  MONTH  DAY  DAY_OF_WEEK  FLIGHT_NUMBER  \
# DESTINATION_AIRPORT AIRLINE
# ABQ                 AA       2015      1    1            4           1662
#                     AA       2015      1    1            4           1024
#                     AA       2015      1    1            4           1203
#                     AA       2015      1    1            4           2388
#                     AA       2015      1    2            5           1662
#
#                             TAIL_NUMBER ORIGIN_AIRPORT  SCHEDULED_DEPARTURE  \
# DESTINATION_AIRPORT AIRLINE
# ABQ                 AA           N4WJAA            DFW                 1045
#                     AA           N505AA            DFW                 1400
#                     AA           N4XPAA            DFW                 1840
#                     AA           N486AA            DFW                 2115
#                     AA           N582AA            DFW                 1045
#
# ...

# %%
df.index.unique()[0:20]
# Out:
# MultiIndex([('ABE', 'DL'),
#             ('ABE', 'EV'),
#             ('ABI', 'MQ'),
#             ('ABQ', 'AA'),
#             ('ABQ', 'AS'),
#             ('ABQ', 'B6'),
#             ('ABQ', 'DL'),
#             ('ABQ', 'EV'),
#             ('ABQ', 'MQ'),
#             ('ABQ', 'OO'),
#             ('ABQ', 'WN'),
#             ('ABR', 'OO'),
#             ('ABY', 'EV'),
#             ('ACT', 'MQ'),
#             ('ACV', 'OO'),
#             ('ACY', 'NK'),
#             ('ADK', 'AS'),
#             ('ADQ', 'AS'),
#             ('AEX', 'EV'),
#             ('AEX', 'MQ')],
#            names=['DESTINATION_AIRPORT', 'AIRLINE'])

# %%
df.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'FLIGHT_NUMBER', 'TAIL_NUMBER',
#        'ORIGIN_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME',
#        'DEPARTURE_DELAY', 'TAXI_OUT', 'WHEELS_OFF', 'SCHEDULED_TIME',
#        'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'WHEELS_ON', 'TAXI_IN',
#        'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME', 'ARRIVAL_DELAY', 'DIVERTED',
#        'CANCELLED'],
#       dtype='object')
