# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("https://github.com/ageron/data/raw/main/lifesat/lifesat.csv")
df.head()
# Out:
#    Country  GDP per capita (USD)  Life satisfaction
# 0   Russia          26456.387938                5.8
# 1   Greece          27287.083401                5.4
# 2   Turkey          28384.987785                5.5
# 3   Latvia          29932.493910                5.9
# 4  Hungary          31007.768407                5.6

# %%
X = df["GDP per capita (USD)"].values
Y = df["Life satisfaction"].values
# Out:
# array([5.8, 5.4, 5.5, 5.9, 5.6, 5.4, 6.1, 5.7, 6.3, 5.9, 5.9, 7.2, 6. ,
#        6.8, 6.5, 7.3, 7.4, 7.6, 6.9, 7.3, 7.3, 7. , 7.1, 7.5, 7.4, 7.6,
#        6.9])

# %%
def linear_regression_fit(X: float, Y: float) ->float:
    X_mean = np.mean(X)
    Y_mean = np.mean(Y)
    a = ((X-X_mean)@(Y-Y_mean))/((X-X_mean)@(X-X_mean))
    b = Y_mean - X_mean * a
    return a, b

# %%
def linear_regression_predict(a: float, b: float,X:float) -> float:
    Y_new = b + a * X
    return Y_new

# %%
X_new = 30000

a, b = linear_regression_fit(X, Y)
pred = linear_regression_predict(a,b,X_new)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,Y)
plt.xlabel("GDP per capita (USD)")
plt.ylabel("Life satisfaction")
plt.plot(X, X*a + b, 'r')
plt.scatter(X_new, pred, color="green", s=100)
plt.show()
